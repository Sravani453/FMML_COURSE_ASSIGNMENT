# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravani453/FMML_COURSE_ASSIGNMENT/blob/main/mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 09:41:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   358MB/s    in 0.2s
#
# 2024-03-25 09:41:50 (358 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30524  1712.04575v1  We consider the problem of fusing an arbitrary...    cs
# 5231    1203.3497v1  Most conventional Reinforcement Learning (RL) ...    cs
# 3729   1803.06111v1  The Renormalisation Group (RG) provides a fram...  stat
# 31748   0901.0753v1  Cooperative decision making is a vision of fut...    cs
# 2399   1505.05004v2  We present a novel hybrid algorithm for Bayesi...  stat
# ...             ...                                                ...   ...
# 22246  1510.02830v1  In this paper we introduce a novel online time...  stat
# 25788  1511.06739v5  In this paper we propose a CNN architecture fo...    cs
# 25540  1509.09243v1  The normal compositional model (NCM) has been ...    cs
# 21681   0909.5422v1  In the last few years, due to the growing ubiq...  stat
# 30820  1801.05173v1  Deep fully convolutional neural network (FCN) ...    cs
#
#                                                    title  year  \
# 30524                   Fusing Multiple Multiband Images  2017
# 5231   Parametric Return Density Estimation for Reinf...  2012
# 3729                      Vulnerability of Deep Learning  2018
# 31748  Distributed Preemption Decisions: Probabilisti...  2009
# 2399   An Experimental Comparison of Hybrid Algorithm...  2015
# ...                                                  ...   ...
# 22246  p-Markov Gaussian Processes for Scalable and E...  2015
# 25788  Superpixel Convolutional Networks using Bilate...  2015
# 25540  A spatial compositional model (SCM) for linear...  2015
# 21681  Laplacian Support Vector Machines Trained in t...  2009
# 30820  Fully Convolutional Multi-scale Residual Dense...  2018
#
#                                                 keywords
# 30524  [arbitrary, multiband, panchromatic, multispec...
# 5231   [conventional, reinforcement, algorithms, espe...
# 3729   [renormalisation, framework, sensitive, suscep...
# 31748  [cooperative, management, distributed, connect...
# 2399   [algorithm, structure, reconstructs, subroutin...
# ...                                                  ...
# 22246  [introduce, forecasting, equivalent, regressio...
# 25788  [architecture, segmentation, introduce, bilate...
# 25540  [compositional, extensively, hyperspectral, es...
# 21681  [unlabeled, community, understanding, classifi...
# 30820  [convolutional, architectures, potential, segm...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30524    [arbitrary, multiband, panchromatic, multispec...
# 5231     [conventional, reinforcement, algorithms, espe...
# 3729     [renormalisation, framework, sensitive, suscep...
# 31748    [cooperative, management, distributed, connect...
# 2399     [algorithm, structure, reconstructs, subroutin...
#                                ...
# 21748    [thesholding, factorization, selection, inform...
# 28596    [ubiquitous, eigenfunctions, representing, fun...
# 1838     [counterfactual, statistical, translation, tra...
# 22665    [clustering, versatile, clustering, relaxation...
# 6738     [variations, classical, procedure, optimisatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8751 words.
# Out of those 4530 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e0a58bb-5177-4d47-a89b-dceddb279c36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e0a58bb-5177-4d47-a89b-dceddb279c36")) {                    Plotly.newPlot(                        "0e0a58bb-5177-4d47-a89b-dceddb279c36",                        [{"x":["complexity","exploiting","likelihood","estimator","observation","belonging","abundance","nonnegativity","potential","variation","comparison","experiments","calculate","panchromatic","abundances","algorithms","estimation","performance","facilitates","multispectral","conjunction","formulate","conditions","perturbations","direction","endmember","regularize","arbitrary","uniqueness","knowledge","constructed","resultant","transform","constraints","alternating","posedness","computational","hyperspectral","optimization","alleviate","convolution","piecewise","algorithm","regularization","multipliers","information","environment","reinforcement","parametric","conventional","densities","paradigms","preferred","conditional","probability","especially","numerical","estimating","sometimes","sensitive","instances","extension","presented","management","distributions","applications","identified","vulnerability","sensitivity","dangerous","corresponding","framework","classification","susceptible","identifying","robustness","operators","existence","directions","different","associated","vulnerable","adversarial","allocating","decentralized","investigates","exchanged","distributed","corresponds","spatially","validated","probabilistic","important","dependent","neighbors","intractable","graphical","challenge","collectively","controlling","intelligent","centralized","optimality","efficient","resources","connection","decisions","cooperative","simulation","computationally","outperforms","subroutine","extensive","benchmarks","dependence","structure","reconstructs","constraint","experimental","currently","empirical","available","incremental","candidates","demonstrate","vocabulary","quantification","outperform","pathologic","subsequent","clinically","supervised","estimated","detection","clustering","identification","categorizing","representation","convolutional","autoencoder","embedding","reference","meaningful","definition","generates","prognosis","categorize","approaches","diagnosis","distribution","anomalies","annotations","impressive","difficult","parameter","successfully","restoration","numerically","automatically","implementation","iteration","denoising","competitive","deblurring","discrepancy","furthermore","techniques","theoretical","challenging","principle","deconvolution","recovering","effective","intelligently","perception","understanding","reasoning","commonsense","navigation","grounding","environments","protocols","answering","evaluation","alternatives","selection","determine","resampling","improvements","predictive","bootstrapping","characteristics","operating","aggregation","variability","refitting","technique","fortunately","considering","bootstrap"],"y":[222,69,59,20,69,10,5,2,147,55,126,601,19,1,2,582,212,891,19,7,15,63,125,19,76,3,11,74,9,341,65,5,72,141,22,3,286,17,339,32,53,14,865,77,14,684,126,131,37,98,11,16,12,84,163,112,90,69,21,55,107,66,167,47,113,438,35,1,27,3,131,564,519,3,77,107,50,33,37,750,92,14,101,3,12,25,4,111,30,24,27,135,361,65,18,24,57,141,7,15,66,8,22,416,73,42,56,13,68,75,246,2,156,98,11,344,4,86,366,57,150,310,27,35,555,40,9,86,2,31,6,218,73,363,166,103,5,376,365,20,116,69,51,47,54,3,7,430,50,213,11,69,15,143,131,90,24,13,182,144,45,36,106,4,24,156,355,179,243,50,11,22,244,4,55,144,122,13,24,6,87,16,62,271,20,174,73,4,113,51,6,96,19,28,18,0,250,2,62,6],"type":"bar"},{"x":["complexity","exploiting","likelihood","estimator","observation","belonging","abundanc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4530,), (4530, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Maxmin</span> <span style='background-color:rgba(0, 255, 0, 0.5973741794310723);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5973741794310723);'>Convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNN)</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>However</span> <span style=''>the</span> <span style=''>way</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.31538461538461543);'>information</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>are</span> <span style=''>encoded</span> <span style=''>through</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>CNN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>is</span> <span style=''>still</span> <span style=''>an</span> <span style=''>open</span> <span style=''>question</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>modify</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>convo</span> <span style=''>lutional</span> <span style=''>block</span> <span style=''>of</span> <span style=''>CNN</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>transfer</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.31538461538461543);'>information</span> <span style=''>layer</span> <span style=''>after</span> <span style=''>layer</span> <span style=''>while</span> <span style=''>keeping</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariance</span> <span style=''>within</span> <span style=''>the</span> <span style=''>net</span> <span style=''>work</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>both</span> <span style=''>positive</span> <span style=''>and</span> <span style=''>negative</span> <span style=''>high</span> <span style=''>scores</span> <span style=''>obtained</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.582089552238806);'>convolution</span> <span style=''>maps</span> <span style=''>This</span> <span style=''>behav</span> <span style=''>ior</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modifying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33079847908745247);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>func</span> <span style=''>tion</span> <span style=''>step</span> <span style=''>before</span> <span style=''>pooling</span> <span style=''>We</span> <span style=''>are</span> <span style=''>doubling</span> <span style=''>the</span> <span style=''>maps</span> <span style=''>with</span> <span style=''>spe</span> <span style=''>cific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activations</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Subspace</span> <span style=''>Sparse</span> <span style=''>Recovery</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Corrupted</span> <span style=''>Data</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimization</span> <br/><br/><span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>often</span> <span style=''>lie</span> <span style=''>in</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>classes</span> <span style=''>they</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>Finding</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>built</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>data</span> <span style=''>helps</span> <span style=''>to</span> <span style=''>uncover</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>and</span> <span style=''>address</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>more</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovering</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>for</span> <span style=''>noisy</span> <span style=''>data</span> <span style=''>points</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>whose</span> <span style=''>columns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>data</span> <span style=''>lying</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>union</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>and</span> <span style=''>study</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>so ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Dropout</span> <span style=''>for</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorization</span> <br/><br/><span style=''>Dropout</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.3118279569892473);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizing</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>by</span> <span style=''>randomly</span> <span style=''>dropping</span> <span style=''>out</span> <span style=''>units</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Bernoulli</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>for</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>problem</span> <span style=''>classes</span> <span style=''>such</span> <span style=''>as</span> <span style=''>linear</span> <span style=''>or</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.4829059829059829);'>regression</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>studies</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>between</span> <span style=''>dropout</span> <span style=''>and</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>Tikhonov</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>regularization</span> <span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>dropout</span> <span style=''>for</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorization</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Bernoulli</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.40966921119592875);'>variables</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>drop</span> <span style=''>a</span> <span style=''>factor</span> <span style=''>thereby</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>attempting</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorization</span> <span style=''>While</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.31446540880503154);'>effectiveness</span> <span style=''>of</span> <span style=''>dropout</span> <span style=''>for</span> <span style=''>matrix</span> <span style='background-color:rgba(255, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparsity</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Extremes</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Capturing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>extreme</span> <span style=''>events</span> <span style=''>is</span> <span style=''>a</span> <span style=''>major</span> <span style=''>concern</span> <span style=''>in</span> <span style=''>many</span> <span style=''>fields</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>of</span> <span style=''>risks</span> <span style=''>stemming</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>sources</span> <span style=''>eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>portfolio</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>insurance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environmental</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>and</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>One</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>(non</span> <span style=''>parametric)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>extremal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>Extreme</span> <span style=''>Value</span> <span style=''>Theory</span> <span style=''>(EVT)</span> <span style=''>is</span> <span style=''>the</span> <span style=''>angular</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>provides</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>probable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>of</span> <span style=''>extremes</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style=''>relative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>of</span> <span style=''>each</span> <span style=''>featurecoordinate</span> <span style=''>of</span> <span style=''>the</span> <span style=''>largest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>Modeling</span> <span style=''>the</span> <span style=''>angular</span> <span style=''>measure</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>problems</span> <span style=''>is</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06451612903225806)
# 	automatic (0.07311827956989247)
# 	architecture (0.08243727598566308)
# 	experimental (0.13118279569892474)
# 	representation (0.13476702508960572)
# 	information (0.24516129032258063)
# 	detection (0.13010752688172042)
# 	convolutional (0.13082437275985664)
# 	different (0.26881720430107525)
# 	recognition (0.13906810035842293)
#
# Some Statistics words are:
# 	stochastic (0.1318407960199005)
# 	theoretical (0.1527363184079602)
# 	variables (0.13781094527363183)
# 	estimation (0.17512437810945275)
# 	algorithm (0.4099502487562189)
# 	statistical (0.15920398009950248)
# 	distribution (0.1865671641791045)
# 	inference (0.19054726368159203)
# 	dimensional (0.18507462686567164)
# 	regression (0.172636815920398)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="985d5577-fd6e-45ca-baa5-667d0d5bf8f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("985d5577-fd6e-45ca-baa5-667d0d5bf8f6")) {                    Plotly.newPlot(                        "985d5577-fd6e-45ca-baa5-667d0d5bf8f6",                        [{"x":["complexity","exploiting","likelihood","estimator","observation","belonging","abundance","nonnegativity","potential","variation","comparison","experiments","calculate","panchromatic","abundances","algorithms","estimation","performance","facilitates","multispectral","conjunction","formulate","conditions","perturbations","direction","endmember","regularize","arbitrary","uniqueness","knowledge","constructed","resultant","transform","constraints","alternating","posedness","computational","hyperspectral","optimization","alleviate","convolution","piecewise","algorithm","regularization","multipliers","information","environment","reinforcement","parametric","conventional","densities","paradigms","preferred","conditional","probability","especially","numerical","estimating","sometimes","sensitive","instances","extension","presented","management","distributions","applications","identified","vulnerability","sensitivity","dangerous","corresponding","framework","classification","susceptible","identifying","robustness","operators","existence","directions","different","associated","vulnerable","adversarial","allocating","decentralized","investigates","exchanged","distributed","corresponds","spatially","validated","probabilistic","important","dependent","neighbors","intractable","graphical","challenge","collectively","controlling","intelligent","centralized","optimality","efficient","resources","connection","decisions","cooperative","simulation","computationally","outperforms","subroutine","extensive","benchmarks","dependence","structure","reconstructs","constraint","experimental","currently","empirical","available","incremental","candidates","demonstrate","vocabulary","quantification","outperform","pathologic","subsequent","clinically","supervised","estimated","detection","clustering","identification","categorizing","representation","convolutional","autoencoder","embedding","reference","meaningful","definition","generates","prognosis","categorize","approaches","diagnosis","distribution","anomalies","annotations","impressive","difficult","parameter","successfully","restoration","numerically","automatically","implementation","iteration","denoising","competitive","deblurring","discrepancy","furthermore","techniques","theoretical","challenging","principle","deconvolution","recovering","effective","intelligently","perception","understanding","reasoning","commonsense","navigation","grounding","environments","protocols","answering","evaluation","alternatives","selection","determine","resampling","improvements","predictive","bootstrapping","characteristics","operating","aggregation","variability","refitting","technique","fortunately","considering","bootstrap","populations","arguments","illustrate","geometrical","relationship","estimators","dimension","predictor","effectively","multivariate","induction","specifically","normality","principal","characterization","unsupervised","components","reduction","architectures","significant","redundancy","accurately","parameterization","predicted","predicting","remaining","parameters","thickness","additionally","progression","tomography","particular","subjected","thresholds","groundtruth","estimates","filtering","respectively","automated","segmentation","iterative","structural","resolution","coherence","segmenting","assumptions","including","factorization","formulation","generalized","individual","trilinear","generalizes","baselines","introduce","function ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	refitting
# 	trilinear
# 	triggering
# 	positivity
# 	robustifying
# 	blockwise
# 	individualized
# 	compounded
# 	proteomics
# 	sparsistent
# 	sufficiency
# 	inverting
# 	varepsilon
# 	burgeoning
# 	formidable
# 	toolboxes
# 	frequentist
# 	transparency
# 	commutative
# 	deteriorates
# Some words which never appear in Statistics papers:
# 	nonnegativity
# 	pathologic
# 	deblurring
# 	commonsense
# 	navigation
# 	subjected
# 	groundtruth
# 	residential
# 	destructive
# 	neurosurgery
# 	displacement
# 	compensation
# 	ultrasound
# 	deformation
# 	formalisms
# 	codification
# 	disambiguation
# 	observers
# 	controllers
# 	circumscription

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0835646006783845e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
